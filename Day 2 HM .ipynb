# %%
x = input("First Name: ")
# Out:
# First Name: Busra Nur

# %%
y = input("Last Name: ")
# Out:
# Last Name: Aydin

# %%
Age = int(input("Age: "))

if Age <= 18:
   print("You can't go out because it's too dangerous!")
if Age > 18:
   print("You can go out to the street...")
# Out:
# Age: 22
# You can go out to the street...

# %%
z = input("Date of Birth: ")
# Out:
# Date of Birth: 6.5.1998
