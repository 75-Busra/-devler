# %%
print ("hi")
type("hi")
# Out:
# hi
# str

# %%
print ("I'm Büşra")
type("I'm Büşra")
# Out:
# I'm Büşra
# str

# %%
print ("I'm 22 years old")
type("I'm 22 years old")
# Out:
# I'm 22 years old
# str

# %%
print ("I'm studying law in Trabzon")
type("I'm studying law in Trabzon")
# Out:
# I'm studying law in Trabzon
# str

# %%
print ("I'm interested in AI")
type("I'm interested in AI")
# Out:
# I'm interested in AI
# str

# %%
name = "earthling"
print (f'hello {name}')
# Out:
# hello earthling

# %%
name2 = "Asil"
print ("My cat name is {}".format(name2))
# Out:
# My cat name is Asil
